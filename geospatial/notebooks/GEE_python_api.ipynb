# %% [markdown]
# # Downloading Data using Google Earth Engine Python API
#
# Note: Before running this notebook make sure you installed the neccesary packges and set up the authentication for GEE as described in the document.
#
# Packages required:
# ```
# pip install earthengine-api
# pip install folium
# pip install geehydro
# ```

# %%
# import packages
import ee
import folium
import geehydro
from IPython.display import Image

# %% [markdown]
# ### Initialize the connection
# When you use the API, the first thing you need to do is to initialize the connection to the server:

# %%
ee.Initialize()

# %% [markdown]
# ###  Area of Interest
# With satellite imagery you can investigate any spot on Earth. Select a region in the world you are interested on. Make sure that the projection for th e coordinates is in epsg:4326

# %%
geometry = ee.Geometry.Polygon([ [ [ 74.78773234410812, 21.0595214900118745 ], [ 74.351701190523794, 21.091442728540564 ], [ 74.38934656420032073, 21.084363329949862 ], [ 74.38561416973411, 21.0568038201353 ], [ 74.2951443234410812, 21.0460214900118745 ], [ 74.78773234410812, 21.0595214900118745 ]  ] ])

# %% [markdown]
# ### The Sentinel 2 Collection
# In GEE each collection has its own id. The snippet id for the LSentinel-2 MSI: MultiSpectral Instrument, Level-2A product is “COPERNICUS/S2_SR”.
#
# You can have access to the Sentinel 2 collection with the following code:

# %%
sentinel2_aoi = ee.ImageCollection("COPERNICUS/S2_SR")

# %% [markdown]
# ### Filtering the collection
# There are many filters you can apply to the collection. Let’s discuss the most common ones.
#
# #### Filtering to the area of interest
# The “.filterBounds()” method allows to select the geometry defined above.
#
# #### Filtering by date range
# The “.filterDate()” method allows to filter by date range.
#
# #### Filtering by Max Percentage of Cloud
# The “ee.Filter.lt(‘CLOUDY_PIXEL_PERCENTAGE’, use_scenes_with_max_cloud_percentage_of)” method allows to filter by cloud percentage.

# %% [markdown]
# #### Masking out clouds
# Most satellite imagery comes with cloud mask that can be used to mask out clouds from imagery. The following function mask out clouds for Sentinel 2 images.

# %%
def maskS2clouds(image):
    qa = image.select('QA60')
    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask);

# %% [markdown]
# #### Combining all filters and getting median image from all images in a date range
#
# Filters can be combined. The following example gives you the median image from all images in a date range with maximum cloud coverage of 3% and clouds masked out

# %%
sentinel2_aoi = ee.ImageCollection("COPERNICUS/S2_SR").filterBounds(geometry)
sentinel2_median_image = sentinel2_aoi.filterDate('2019-05-15', '2019-05-30').filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',3)).map(maskS2clouds).median()

# %% [markdown]
# ### Meta-data
# You can easily .getInfo() about the Landsat collection above or any particular information you might be interested in.

# %%
sentinel2_aoi.getInfo()
# Out:
# {'type': 'ImageCollection',
#  'bands': [],
#  'id': 'COPERNICUS/S2_SR',
#  'version': 1594224370641414,
#  'properties': {'date_range': [1490659200000, 1593907200000],
#   'period': 0,
#   'system:visualization_0_min': '0.0',
#   'type_name': 'ImageCollection',
#   'system:visualization_0_bands': 'B4,B3,B2',
#   'thumb': 'https://mw1.google.com/ges/dd/images/COPERNICUS_S2_SR_thumb.png',
#   'description': '<p>Sentinel-2 is a wide-swath, high-resolution, multi-spectral\nimaging mission supporting Copernicus Land Monitoring studies,\nincluding the monitoring of vegetation, soil and water cover,\nas well as observation of inland waterways and coastal areas.</p><p>The Sentinel-2 L2 data are downloaded from scihub. They were\ncomputed by running sen2cor. WARNING: ESA did not produce L2 data\nfor all L1 assets, and earlier L2 coverage is not global.</p><p>The assets contain\n12 UINT16 spectral bands representing SR scaled by 10000 (unlike in L1 data,\nthere is no B10). There are also several more L2-specific bands (see band\nlist for details). See the\n<a href="https://sentinel.esa.int/documents/247904/685211/Sentinel-2_User_Handbook">Sentinel-2 User Handbook</a>\nfor details. In addition, three QA bands are present where one\n(QA60) is a bitmask band with cloud mask information. For more\ndetails, <a href="https://sentinel.esa.int/web/sentinel/technical-guides/sentinel-2-msi/level-1c/cloud-masks">see the full explanation of how cloud masks are computed.</a></p><p>EE asset ids for Sentinel-2 L2 assets have the following format:\nCOPERNICUS/S2_SR/20151128T002653_20151128T102149_T56MNN. Here the\nfirst numeric part represents the sensing date and time, the\nsecond numeric part represents the product generation date and\ntime, and the final 6-character string is a unique granule identifier\nindicating its UTM grid reference (see <a href="https://en.wikipedia.org/wiki/Military_Grid_Reference_System">MGRS</a>).</p><p>For more details on Sentinel-2 radiometric resolution, <a href="https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/resolutions/radiometric">see this page</a>.</p><p><b>Revisit Interval</b><br>\n  5 days\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Units</th><th scope="col">Min</th><th scope="col">Max</th><th scope="col">Scale</th><th scope="col">Resolution</th><th scope="col">Wavelength</th><th scope="col">Description</th></tr><tr><td>B1</td><td></td><td></td><td></td><td>0.0001</td><td>\n      60 meters\n</td><td>443.9nm (S2A) / 442.3nm (S2B)</td><td><p>Aerosols</p></td></tr><tr><td>B2</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>496.6nm (S2A) / 492.1nm (S2B)</td><td><p>Blue</p></td></tr><tr><td>B3</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>560nm (S2A) / 559nm (S2B)</td><td><p>Green</p></td></tr><tr><td>B4</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>664.5nm (S2A) / 665nm (S2B)</td><td><p>Red</p></td></tr><tr><td>B5</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>703.9nm (S2A) / 703.8nm (S2B)</td><td><p>Red Edge 1</p></td></tr><tr><td>B6</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>740.2nm (S2A) / 739.1nm (S2B)</td><td><p>Red Edge 2</p></td></tr><tr><td>B7</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>782.5nm (S2A) / 779.7nm (S2B)</td><td><p>Red Edge 3</p></td></tr><tr><td>B8</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>835.1nm (S2A) / 833nm (S2B)</td><td><p>NIR</p></td></tr><tr><td>B8A</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>864.8nm (S2A) / 864nm (S2B)</td><td><p>Red Edge 4</p></td></tr><tr><td>B9</td><td></td><td></td><td></td><td>0.0001</td><td>\n      60 meters\n</td><td>945nm (S2A) / 943.2nm (S2B)</td><td><p>Water vapor</p></td></tr><tr><td>B11</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>1613.7nm (S2A) / 1610.4nm (S2B)</td><td><p>SWIR 1</p></td></tr><tr><td>B12</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>2202.4nm (S2A) / 2185.7nm (S2B)</td><td><p>SWIR 2</p></td></tr><tr><td>AOT</td><td></td><td></td><td></td><td>0.001</td><td>\n      10 meters\n</td><td></td><td><p>Aerosol Optical Thickness</p></td></tr><tr><td>WVP</td><td> ...
#   'source_tags': ['eu', 'esa', 'copernicus', 'sentinel'],
#   'visualization_0_max': '3000.0',
#   'provider_url': 'https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/product-types/level-2a',
#   'title': 'Sentinel-2 MSI: MultiSpectral Instrument, Level-2A',
#   'sample': 'https://mw1.google.com/ges/dd/images/COPERNICUS_S2_SR_sample.png',
#   'tags': ['eu', 'esa', 'copernicus', 'sentinel', 'msi', 'sr', 'reflectance'],
#   'system:visualization_0_max': '3000.0',
#   'product_tags': ['msi', 'sr', 'reflectance'],
#   'provider': 'European Union/ESA/Copernicus',
#   'visualization_0_min': '0.0',
#   'system:visualization_0_name': 'RGB',
#   'visualization_0_name': 'RGB',
#   'visualization_0_bands': 'B4,B3,B2'},
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32643',
#      'crs_transform': [60, 0, 399960, 0, -60, 2400000]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32643',
#      'crs_transform': [60, 0, 399960, 0, -60, 2400000]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32643',
#      'crs_transform': [10, 0, 399960, 0, -10, 2400000]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32643',
#      'crs_transform': [20, 0, 399960, 0, -20, 2400000]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32643',
#      'crs_transform': [60, 0, 399960, 0, -60, 2400000]}],
#    'id': 'COPERNICUS/S2_SR/20181216T053229_20181216T053648_T43QDD',
#    'version': 1557019036764824,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20181216T053229_009283_N02.11',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 101.827653676,
#     'CLOUD_SHADOW_PERCENTAGE': 0.002512,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 156.882544566,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[75.09417836584879, 21.703479811089462],
#       [75.09416624781078, 21.703480566373408],
#       [74.03286590029424, 21.700686426771668],
#       [74.03282152315424, 21.700649616410885],
#       [74.03277257381208, 21.7006182803775],
#       [74.03276961533496, 21.700603489581212],
#       [74.03603484959169, 21.204726545453685],
#       [74.03920670448203, 20.708827583767803],
#       [74.03924605985753, 20.708786330930327],
#       [74.03927958812089, 20.70874081564098],
#       [74.03929536612513, 20.70873815527809],
#       [75.09353931628873, 20.711392827905236],
#       [75.09358368986327, 20.711429373301588],
#       [75.09363260770519, 20.711460465337474],
#       [75.09363563722495, 20.71147518855895],
#       [75.09426301388268, 21.70339046877172],
#       [75.09422371937994, 21.70343195606705],
#       [75.09419030567946, 21.70347770837096],
#       [75.09417836584879, 21.703479811089462]]},
#     'VEGETATION_PERCENTAGE': 9.397262,
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 
#       [75.09353931628873, 20.711392827905236],
#       [75.09358368986327, 20.711429373301588],
#       [75.09363260770519, 20.711460465337474],
#       [75.09363563722495, 20.71147518855895],
#       [75.09426301388268, 21.70339046877172],
#       [75.09422371937994, 21.70343195606705],
#       [75.09419030567946, 21.70347770837096],
#       [75.09417836584879, 21.703479811089462]]},
#     'VEGETATION_PERCENTAGE': 12.165783,
#     'SOLAR_IRRADIANCE_B12': 85.25,
#     'SOLAR_IRRADIANCE_B10': 367.15,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 245.59,
#     'GENERATION_TIME': 1593768263000,
#     'SOLAR_IRRADIANCE_B8A': 955.32,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 65.007447,
#     'THIN_CIRRUS_PERCENTAGE': 26.806393,
#     'system:time_end': 1593754994277,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1593754994277,
#     'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_EPAE_20200703T092423_S20200703T053446_N02.14',
#     'PROCESSING_BASELINE': '02.14',
#     'SENSING_ORBIT_NUMBER': 105,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T43QDD_A026271_20200703T053446',
#     'REFLECTANCE_CONVERSION_CORRECTION': 0.967480259147404,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 24.8528,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 103.58283394228,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 100.362391205483,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 101.050011017866,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 100.794836865618,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 101.902632113062,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.75296058037234,
#     'NOT_VEGETATED_PERCENTAGE': 12.629199,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 101.37478062175,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 104.477413475711,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 102.873083048793,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 4.50555915103834,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 100.518165192058,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 4.44568653447001,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 4.36024748376897,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 4.28247021017168,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.825604584741,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 4.31869052675132,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 4.62487449468538,
#     'DARK_FEATURES_PERCENTAGE': 0.643488,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 13.348253,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 4.56341421143445,
#     'UNCLASSIFIED_PERCENTAGE': 9.339803,
#     'MEAN_SOLAR_ZENITH_ANGLE': 19.247670808053,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 4.68954518812826,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '43QDD',
#     'CLOUDY_PIXEL_PERCENTAGE': 65.007447,
#     'PRODUCT_ID': 'S2A_MSIL2A_20200703T052651_N0214_R105_T43QDD_20200703T092423',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 4.42026713249057,
#     'SOLAR_IRRADIANCE_B9': 812.92,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 4.5530724915998,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 4.70341031420182,
#     'SOLAR_IRRADIANCE_B6': 1287.61,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 102.003257259448,
#     'SOLAR_IRRADIANCE_B5': 1424.64,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 101.049238203365,
#     'SOLAR_IRRADIANCE_B8': 1041.63,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 100.482286305194,
#     'SOLAR_IRRADIANCE_B7': 1162.08,
#     'SOLAR_IRRADIANCE_B2': 1959.66,
#     'SOLAR_IRRADIANCE_B1': 1884.69,
#     'SOLAR_IRRADIANCE_B4': 1512.06,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1823.24,
#     'system:asset_size': 1658033548,
#     'WATER_PERCENTAGE': 0.111051,
#     'system:index': '20200703T052651_20200703T053446_T43QDD'}}]}

# %% [markdown]
#  It’s possible to be more selective and filter out the information you don’t want.

# %%
sentinel2_aoi.size().getInfo()
# Out:
# 113

# %% [markdown]
# ### Visualizing the Images
#
# The Javascript-based code editor easily allows interactive visualization using ```Map.AddLayer()```, but unfortunately, this is not available for the standard Python API. A simple, static map can be made with both the ```.getThumbURL()``` module from ee and the native ```.display()``` module:

# %%
# Visualizing the first image in the collection
rgbVis = {
    'min': 0.0,
    'max': 3000.0,
    'bands': ['B4', 'B3', 'B2'],
    'region': geometry}
first_img = ee.Image(sentinel2_mh_aoi.first())
Image(url= first_img.getThumbUrl(rgbVis))

# %%
center = geometry.centroid().coordinates()
mh_map = folium.Map(location=[center.get(1).getInfo(), center.get(0).getInfo()], zoom_start=10)
mh_map.addLayer(first_img, rgbVis)
mh_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ```geehydro``` allows an even greater degree of reproducibility between the Javascript and Python API. It allows for multiple layer to ve vizualize at the same time. The following code shows both the first image in the collection and the median image as well as the OSM layer and allows you to choose the one you want to display.

# %%
# Use folium to visualize different data layers.
mapid = sentinel2_mh_median_image.getMapId({'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000})
map = folium.Map(location=[center.get(1).getInfo(), center.get(0).getInfo()], zoom_start=10)
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Google Earth Engine',
    overlay=True,
    name='median composite',
  ).add_to(map)
mapid = first_img.getMapId({'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000})
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Google Earth Engine',
    overlay=True,
    name='First Image',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
